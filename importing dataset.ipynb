# %%
#importing libraries
import pandas as pd
import requests

# %%
#importing dataset using tmdb API
response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=bbb26402d6e15da91ca8fddc3385d554&primary_release_year=2020')
highest_revenue = response.json()
highest_revenue_films = highest_revenue['results']

# define column names for our new dataframe
columns = ['adult', 'original_language', 'original_title', 'release_date']
# create dataframe with adult, original_language, original_title, release_date columns
df_api = pd.DataFrame(highest_revenue_films, columns = columns)
print(df_api)
# Out:
#     adult original_language                               original_title  \
# 0   False                en   Deathstroke: Knights & Dragons - The Movie
# 1   False                ja                               劇場版「鬼滅の刃」無限列車編
# 2   False                fr           Comment je suis devenu super-héros
# 3   False                en                                          Ava
# 4   False                en                           Black Water: Abyss
# 5   False                fr  Miraculous World : New York, les héros unis
# 6   False                en                               Monster Hunter
# 7   False                en                        The Croods: A New Age
# 8   False                en                            After We Collided
# 9   False                en                            Wonder Woman 1984
# 10  False                en                                         Soul
# 11  False                ja                                   イエスかノーか半分か
# ...

# %%
df_api.head()
# Out:
#    adult original_language                              original_title  \
# 0  False                en  Deathstroke: Knights & Dragons - The Movie
# 1  False                ja                              劇場版「鬼滅の刃」無限列車編
# 2  False                fr          Comment je suis devenu super-héros
# 3  False                en                                         Ava
# 4  False                en                          Black Water: Abyss
#
#   release_date
# 0   2020-08-04
# 1   2020-10-16
# 2   2020-11-19
# 3   2020-07-02
# 4   2020-07-09

# %%
#importing dataset using pandas
df_pandas = pd.read_csv('C:/Users/ps/DataAnalysis/hungary_chickenpox.csv')

# %%
df_pandas.head()
# Out:
#          Date  BUDAPEST  BARANYA  BACS  BEKES  BORSOD  CSONGRAD  FEJER  GYOR  \
# 0  03/01/2005       168       79    30    173     169        42    136   120
# 1  10/01/2005       157       60    30     92     200        53     51    70
# 2  17/01/2005        96       44    31     86      93        30     93    84
# 3  24/01/2005       163       49    43    126      46        39     52   114
# 4  31/01/2005       122       78    53     87     103        34     95   131
#
#    HAJDU  ...  JASZ  KOMAROM  NOGRAD  PEST  SOMOGY  SZABOLCS  TOLNA  VAS  \
# 0    162  ...   130       57       2   178      66        64     11   29
# 1     84  ...    80       50      29   141      48        29     58   53
# 2    191  ...    64       46       4   157      33        33     24   18
# 3    107  ...    63       54      14   107      66        50     25   21
# 4    172  ...    61       49      11   124      63        56      7   47
#
#    VESZPREM  ZALA
# 0        87    68
# 1        68    26
# ...

# %%
#importing dataset using SQL

# %%
#working on datasets
df_pandas.tail()
# Out:
#            Date  BUDAPEST  BARANYA  BACS  BEKES  BORSOD  CSONGRAD  FEJER  \
# 517  01/12/2014        95       12    41      6      39         0     16
# 518  08/12/2014        43       39    31     10      34         3      2
# 519  15/12/2014        35        7    15      0       0         0      7
# 520  22/12/2014        30       23     8      0      11         4      1
# 521  29/12/2014       259       42    49     32      38        15     11
#
#      GYOR  HAJDU  ...  JASZ  KOMAROM  NOGRAD  PEST  SOMOGY  SZABOLCS  TOLNA  \
# 517    15     14  ...    56        7      13   122       4        23      4
# 518    30     25  ...    34       20      18    70      36         5     23
# 519     7      4  ...    30       36       4    72       5        21     14
# 520     9     10  ...    27       17      21    12       5        17      1
# 521    98     61  ...   112       61      53   256      45        39     27
#
#      VAS  VESZPREM  ZALA
# 517   11       110    10
# ...

# %%
df_pandas.shape
# Out:
# (522, 21)

# %%
df_pandas.describe()
# Out:
#          BUDAPEST     BARANYA        BACS       BEKES      BORSOD    CSONGRAD  \
# count  522.000000  522.000000  522.000000  522.000000  522.000000  522.000000
# mean   101.245211   34.204981   37.166667   28.911877   57.082375   31.488506
# std     76.354872   32.567222   36.843095   37.618092   50.725437   33.790208
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     34.250000    8.000000    8.000000    4.000000   14.250000    6.000000
# 50%     93.000000   25.000000   29.500000   14.000000   46.500000   20.500000
# 75%    149.000000   51.000000   53.000000   38.750000   83.750000   47.000000
# max    479.000000  194.000000  274.000000  271.000000  355.000000  199.000000
#
#             FEJER        GYOR       HAJDU       HEVES        JASZ     KOMAROM  \
# count  522.000000  522.000000  522.000000  522.000000  522.000000  522.000000
# mean    33.272031   41.436782   47.097701   29.691571   40.869732   25.643678
# ...

# %%
df_pandas.columns
# Out:
# Index(['Date', 'BUDAPEST', 'BARANYA', 'BACS', 'BEKES', 'BORSOD', 'CSONGRAD',
#        'FEJER', 'GYOR', 'HAJDU', 'HEVES', 'JASZ', 'KOMAROM', 'NOGRAD', 'PEST',
#        'SOMOGY', 'SZABOLCS', 'TOLNA', 'VAS', 'VESZPREM', 'ZALA'],
#       dtype='object')

# %%
df_pandas.nunique()
# Out:
# Date        522
# BUDAPEST    217
# BARANYA     114
# BACS        120
# BEKES       110
# BORSOD      160
# CSONGRAD    113
# FEJER       110
# GYOR        123
# HAJDU       140
# HEVES       105
# JASZ        126
# KOMAROM      86
# NOGRAD       82
# PEST        196
# SOMOGY       96
# SZABOLCS    104
# TOLNA        83
# VAS          90
# VESZPREM    128
# ZALA         80
# dtype: int64

# %%
df_pandas.isnull().sum()
# Out:
# Date        0
# BUDAPEST    0
# BARANYA     0
# BACS        0
# BEKES       0
# BORSOD      0
# CSONGRAD    0
# FEJER       0
# GYOR        0
# HAJDU       0
# HEVES       0
# JASZ        0
# KOMAROM     0
# NOGRAD      0
# PEST        0
# SOMOGY      0
# SZABOLCS    0
# TOLNA       0
# VAS         0
# VESZPREM    0
# ZALA        0
# dtype: int64
